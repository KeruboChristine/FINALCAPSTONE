# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
# Load IPC dataset
df = pd.read_excel("ipcphase.xlsx")

print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.

# %%
# Display first five rows
df.head()
# Out:
#    row source_organization               source_document country country_code  \
# 0    0            FEWS NET  Food Security Outlook, Kenya   Kenya           KE
# 1    1            FEWS NET  Food Security Outlook, Kenya   Kenya           KE
# 2    2            FEWS NET  Food Security Outlook, Kenya   Kenya           KE
# 3    3            FEWS NET  Food Security Outlook, Kenya   Kenya           KE
# 4    4            FEWS NET  Food Security Outlook, Kenya   Kenya           KE
#
#   geographic_group fewsnet_region                   geographic_unit_full_name  \
# 0   Eastern Africa    East Africa  Aberdare Forest1, Murang'a, Central, Kenya
# 1   Eastern Africa    East Africa  Aberdare Forest1, Murang'a, Central, Kenya
# 2   Eastern Africa    East Africa  Aberdare Forest1, Murang'a, Central, Kenya
# 3   Eastern Africa    East Africa  Aberdare Forest1, Murang'a, Central, Kenya
# 4   Eastern Africa    East Africa  Aberdare Forest1, Murang'a, Central, Kenya
#
#   geographic_unit_name  unit_type            fnid classification_scale  \
# 0     Aberdare Forest1  fsc_admin  KE2011C1480401              IPC 2.0
# 1     Aberdare Forest1  fsc_admin  KE2011C1480401              IPC 2.0
# 2     Aberdare Forest1  fsc_admin  KE2011C1480401              IPC 2.0
# 3     Aberdare Forest1  fsc_admin  KE2011C1480401              IPC 2.0
# 4     Aberdare Forest1  fsc_admin  KE2011C1480401              IPC 2.0
#
#        scenario_name  preference_rating  is_allowing_for_assistance  \
# 0  Current Situation                 90                       False
# 1  Current Situation                 90                       False
# 2  Current Situation                 90                       False
# 3  Current Situation                 90                       False
# 4  Current Situation                 90                       False
#
#   projection_start projection_end     status  value  pct_phase3  pct_phase4  \
# 0       2011-07-01     2011-07-31  Collected    1.0         NaN         NaN
# 1       2011-10-01     2011-10-31  Collected    1.0         NaN         NaN
# 2       2012-01-01     2012-01-31  Collected    1.0         NaN         NaN
# 3       2012-04-01     2012-04-30  Collected    1.0         NaN         NaN
# 4       2012-07-01     2012-07-31  Collected    1.0         NaN         NaN
#
#    pct_phase5 description        id  datacollectionperiod  datacollection  \
# 0         NaN     Minimal  24679004                160280          168956
# 1         NaN     Minimal  24679007                160283          168957
# 2         NaN     Minimal  24679010                160286          168958
# 3         NaN     Minimal  24679013                160289          168959
# 4         NaN     Minimal  24679016                160292          168960
#
#   scenario  geographic_unit  datasourceorganization  datasourcedocument  \
# 0       CS            22976                       1                6549
# 1       CS            22976                       1                6549
# 2       CS            22976                       1                6549
# 3       CS            22976                       1                6549
# 4       CS            22976                       1                6549
#
#    dataseries                                    dataseries_name  \
# 0     6515156  Aberdare Forest1, Murang'a, Central, Kenya (01...
# 1     6515156  Aberdare Forest1, Murang'a, Central, Kenya (01...
# 2     6515156  Aberdare Forest1, Murang'a, Central, Kenya (01...
# 3     6515156  Aberdare Forest1, Murang'a, Central, Kenya (01...
# 4     6515156  Aberdare Forest1, Murang'a, Central, Kenya (01...
#
#   specialization_type dataseries_specialization_type data_usage_policy  \
# 0          /IPCPhase/            /IPCClassification/            Public
# 1          /IPCPhase/            /IPCClassification/            Public
# 2          /IPCPhase/            /IPCClassification/            Public
# 3          /IPCPhase/            /IPCClassification/            Public
# 4          /IPCPhase/            /IPCClassification/            Public
#
#                created             modified       status_changed  \
# 0  2020-11-25T18:47:21  2020-11-25T18:47:21  2020-11-25T18:53:10
# 1  2020-11-25T18:47:21  2020-11-25T18:47:21  2020-11-25T18:53:10
# 2  2020-11-25T18:47:21  2020-11-25T18:47:21  2020-11-25T18:53:10
# 3  2020-11-25T18:47:21  2020-11-25T18:47:21  2020-11-25T18:53:10
# 4  2020-11-25T18:47:21  2020-11-25T18:47:21  2020-11-25T18:53:10
#
#   collection_status collection_status_changed collection_schedule  \
# 0         Published       2021-01-05T21:16:32              Ad Hoc
# 1         Published       2021-01-05T21:16:32              Ad Hoc
# 2         Published       2021-01-05T21:16:32              Ad Hoc
# 3         Published       2021-01-05T21:16:32              Ad Hoc
# 4         Published       2021-01-05T21:16:31              Ad Hoc
#
#   reporting_date
# 0     2011-07-01
# 1     2011-10-01
# 2     2012-01-01
# 3     2012-04-01
# 4     2012-07-01

# %%
# Display last five rows
df.tail()
# Out:
#          row source_organization               source_document country  \
# 27689  27689            FEWS NET  Food Security Outlook, Kenya   Kenya
# 27690  27690            FEWS NET  Food Security Outlook, Kenya   Kenya
# 27691  27691            FEWS NET  Food Security Outlook, Kenya   Kenya
# 27692  27692            FEWS NET  Food Security Outlook, Kenya   Kenya
# 27693  27693            FEWS NET  Food Security Outlook, Kenya   Kenya
#
#       country_code geographic_group fewsnet_region  \
# 27689           KE   Eastern Africa    East Africa
# 27690           KE   Eastern Africa    East Africa
# 27691           KE   Eastern Africa    East Africa
# 27692           KE   Eastern Africa    East Africa
# 27693           KE   Eastern Africa    East Africa
#
#              geographic_unit_full_name geographic_unit_name  unit_type  \
# 27689  Yatta, Machakos, Eastern, Kenya                Yatta  fsc_admin
# 27690  Yatta, Machakos, Eastern, Kenya                Yatta  fsc_admin
# 27691  Yatta, Machakos, Eastern, Kenya                Yatta  fsc_admin
# 27692  Yatta, Machakos, Eastern, Kenya                Yatta  fsc_admin
# 27693  Yatta, Machakos, Eastern, Kenya                Yatta  fsc_admin
#
#                  fnid classification_scale      scenario_name  \
# 27689  KE2011C1500411              IPC 2.0  Current Situation
# 27690  KE2011C1500411              IPC 2.0  Current Situation
# 27691  KE2011C1500411              IPC 2.0  Current Situation
# 27692  KE2011C1500411              IPC 2.0  Current Situation
# 27693  KE2011C1500411              IPC 2.0  Current Situation
#
#        preference_rating  is_allowing_for_assistance projection_start  \
# 27689                 90                       False       2015-01-01
# 27690                 90                       False       2015-04-01
# 27691                 90                       False       2015-07-01
# 27692                 90                       False       2015-10-01
# 27693                 90                       False       2016-02-01
#
#       projection_end     status  value  pct_phase3  pct_phase4  pct_phase5  \
# 27689     2015-01-31  Collected    1.0         NaN         NaN         NaN
# 27690     2015-04-30  Collected    1.0         NaN         NaN         NaN
# 27691     2015-07-31  Collected    1.0         NaN         NaN         NaN
# 27692     2015-10-31  Collected    1.0         NaN         NaN         NaN
# 27693     2016-02-29  Collected    1.0         NaN         NaN         NaN
#
#       description        id  datacollectionperiod  datacollection scenario  \
# 27689     Minimal  24684599                160320          168970       CS
# 27690     Minimal  24684602                160323          168971       CS
# 27691     Minimal  24684605                160326          168972       CS
# 27692     Minimal  24684608                160329          168973       CS
# 27693     Minimal  24684611                160332          168974       CS
#
#        geographic_unit  datasourceorganization  datasourcedocument  \
# 27689            23077                       1                6549
# 27690            23077                       1                6549
# 27691            23077                       1                6549
# 27692            23077                       1                6549
# 27693            23077                       1                6549
#
#        dataseries                                    dataseries_name  \
# 27689     6515505  Yatta, Machakos, Eastern, Kenya (01/01/2011 - ...
# 27690     6515505  Yatta, Machakos, Eastern, Kenya (01/01/2011 - ...
# 27691     6515505  Yatta, Machakos, Eastern, Kenya (01/01/2011 - ...
# 27692     6515505  Yatta, Machakos, Eastern, Kenya (01/01/2011 - ...
# 27693     6515505  Yatta, Machakos, Eastern, Kenya (01/01/2011 - ...
#
#       specialization_type dataseries_specialization_type data_usage_policy  \
# 27689          /IPCPhase/            /IPCClassification/            Public
# 27690          /IPCPhase/            /IPCClassification/            Public
# 27691          /IPCPhase/            /IPCClassification/            Public
# 27692          /IPCPhase/            /IPCClassification/            Public
# 27693          /IPCPhase/            /IPCClassification/            Public
#
#                    created             modified       status_changed  \
# 27689  2020-11-25T18:48:06  2020-11-25T18:48:06  2020-11-25T18:53:10
# 27690  2020-11-25T18:48:06  2020-11-25T18:48:06  2020-11-25T18:53:10
# 27691  2020-11-25T18:48:06  2020-11-25T18:48:06  2020-11-25T18:53:10
# 27692  2020-11-25T18:48:07  2020-11-25T18:48:07  2020-11-25T18:53:10
# 27693  2020-11-25T18:48:07  2020-11-25T18:48:07  2020-11-25T18:53:10
#
#       collection_status collection_status_changed collection_schedule  \
# 27689         Published       2021-01-05T21:16:29              Ad Hoc
# 27690         Published       2021-01-05T21:16:29              Ad Hoc
# 27691         Published       2021-01-05T21:16:28              Ad Hoc
# 27692         Published       2021-01-05T21:16:28              Ad Hoc
# 27693         Published       2021-01-05T21:16:28              Ad Hoc
#
#       reporting_date
# 27689     2015-01-01
# 27690     2015-04-01
# 27691     2015-07-01
# 27692     2015-10-01
# 27693     2016-02-01

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 27694
# Number of columns: 42

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27694 entries, 0 to 27693
# Data columns (total 42 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   row                             27694 non-null  int64
#  1   source_organization             27694 non-null  str
#  2   source_document                 27694 non-null  str
#  3   country                         27694 non-null  str
#  4   country_code                    27694 non-null  str
#  5   geographic_group                27694 non-null  str
#  6   fewsnet_region                  27694 non-null  str
#  7   geographic_unit_full_name       27694 non-null  str
#  8   geographic_unit_name            27694 non-null  str
#  9   unit_type                       27694 non-null  str
#  10  fnid                            27694 non-null  str
#  11  classification_scale            27694 non-null  str
#  12  scenario_name                   27694 non-null  str
#  13  preference_rating               27694 non-null  int64
#  14  is_allowing_for_assistance      27694 non-null  bool
#  15  projection_start                27694 non-null  str
#  16  projection_end                  27694 non-null  str
#  17  status                          27694 non-null  str
#  18  value                           27694 non-null  float64
#  19  pct_phase3                      0 non-null      float64
#  20  pct_phase4                      0 non-null      float64
#  21  pct_phase5                      0 non-null      float64
#  22  description                     27694 non-null  str
#  23  id                              27694 non-null  int64
#  24  datacollectionperiod            27694 non-null  int64
#  25  datacollection                  27694 non-null  int64
#  26  scenario                        27694 non-null  str
#  27  geographic_unit                 27694 non-null  int64
#  28  datasourceorganization          27694 non-null  int64
#  29  datasourcedocument              27694 non-null  int64
#  30  dataseries                      27694 non-null  int64
#  31  dataseries_name                 27694 non-null  str
#  32  specialization_type             27694 non-null  str
#  33  dataseries_specialization_type  27694 non-null  str
#  34  data_usage_policy               27694 non-null  str
#  35  created                         27694 non-null  str
#  36  modified                        27694 non-null  str
#  37  status_changed                  27694 non-null  str
#  38  collection_status               27694 non-null  str
#  39  collection_status_changed       27694 non-null  str
#  40  collection_schedule             27694 non-null  str
#  41  reporting_date                  27694 non-null  str
# dtypes: bool(1), float64(4), int64(9), str(28)
# memory usage: 8.7 MB

# %%
df.describe()
# Out:
#                 row  preference_rating         value  pct_phase3  pct_phase4  \
# count  27694.000000            27694.0  27694.000000         0.0         0.0
# mean   13846.500000               90.0      1.647505         NaN         NaN
# std     7994.713514                0.0      0.754312         NaN         NaN
# min        0.000000               90.0      1.000000         NaN         NaN
# 25%     6923.250000               90.0      1.000000         NaN         NaN
# 50%    13846.500000               90.0      1.000000         NaN         NaN
# 75%    20769.750000               90.0      2.000000         NaN         NaN
# max    27693.000000               90.0      4.000000         NaN         NaN
#
#        pct_phase5            id  datacollectionperiod  datacollection  \
# count         0.0  2.769400e+04          27694.000000    27694.000000
# mean          NaN  2.734648e+07         206349.731422   216944.804940
# std           NaN  4.666785e+06          71145.803844    73109.200998
# min           NaN  2.435676e+07         158525.000000   168256.000000
# 25%           NaN  2.468675e+07         160295.000000   168961.000000
# 50%           NaN  2.470706e+07         160337.000000   168975.000000
# 75%           NaN  3.042534e+07         278877.000000   295427.000000
# max           NaN  4.144122e+07         378017.000000   388818.000000
#
#        geographic_unit  datasourceorganization  datasourcedocument  \
# count     27694.000000                 27694.0             27694.0
# mean      29320.566296                     1.0              6549.0
# std        6078.219205                     0.0                 0.0
# min       22892.000000                     1.0              6549.0
# 25%       23319.000000                     1.0              6549.0
# 50%       32300.000000                     1.0              6549.0
# 75%       32547.000000                     1.0              6549.0
# max      184237.000000                     1.0              6549.0
#
#          dataseries
# count  2.769400e+04
# mean   6.579163e+06
# std    1.450098e+05
# min    6.471043e+06
# 25%    6.498870e+06
# 50%    6.515532e+06
# 75%    6.516931e+06
# max    6.899733e+06

# %%
df.describe(include='object')
# Out:
#        source_organization               source_document country country_code  \
# count                27694                         27694   27694        27694
# unique                   1                             1       1            1
# top               FEWS NET  Food Security Outlook, Kenya   Kenya           KE
# freq                 27694                         27694   27694        27694
#
#        geographic_group fewsnet_region  \
# count             27694          27694
# unique                1              1
# top      Eastern Africa    East Africa
# freq              27694          27694
#
#                                 geographic_unit_full_name  \
# count                                               27694
# unique                                               1218
# top     Central Highlands, High Potential Zone, Buuri,...
# freq                                                   28
#
#                geographic_unit_name      unit_type              fnid  \
# count                         27694          27694             27694
# unique                          593              3              1218
# top     Western High Potential Zone  fsc_admin_lhz  KE2016C312010019
# freq                           2436          17920                28
#
#        classification_scale      scenario_name projection_start  \
# count                 27694              27694            27694
# unique                    3                  1               49
# top                 IPC 2.0  Current Situation       2020-10-01
# freq                  14874              27694              642
#
#        projection_end     status description scenario  \
# count           27694      27694       27694    27694
# unique             49          1           4        1
# top        2020-10-31  Collected     Minimal       CS
# freq              642      27694       14272    27694
#
#                                           dataseries_name specialization_type  \
# count                                               27694               27694
# unique                                               2897                   1
# top     Aberdare Forest1, Murang'a, Central, Kenya (01...          /IPCPhase/
# freq                                                   19               27694
#
#        dataseries_specialization_type data_usage_policy              created  \
# count                           27694             27694                27694
# unique                              1                 1                  658
# top               /IPCClassification/            Public  2021-07-01T14:05:23
# freq                            27694             27694                  127
#
#                    modified       status_changed collection_status  \
# count                 27694                27694             27694
# unique                  680                   94                 1
# top     2021-07-01T14:05:23  2020-11-25T18:53:10         Published
# freq                    127                 6750             27694
#
#        collection_status_changed collection_schedule reporting_date
# count                      27694               27694          27694
# unique                        27                   1             49
# top          2021-01-05T21:16:27              Ad Hoc     2020-10-01
# freq                        2560               27694            642

# %%
missing = df.isnull().sum()

missing = pd.DataFrame({
    'Missing Values': missing,
    'Percentage': (missing/len(df))*100
})

missing.sort_values(
    by='Percentage',
    ascending=False
)
# Out:
#                                 Missing Values  Percentage
# pct_phase5                               27694       100.0
# pct_phase4                               27694       100.0
# pct_phase3                               27694       100.0
# source_document                              0         0.0
# country_code                                 0         0.0
# geographic_group                             0         0.0
# fewsnet_region                               0         0.0
# country                                      0         0.0
# row                                          0         0.0
# source_organization                          0         0.0
# unit_type                                    0         0.0
# geographic_unit_name                         0         0.0
# geographic_unit_full_name                    0         0.0
# fnid                                         0         0.0
# is_allowing_for_assistance                   0         0.0
# classification_scale                         0         0.0
# scenario_name                                0         0.0
# preference_rating                            0         0.0
# status                                       0         0.0
# projection_end                               0         0.0
# projection_start                             0         0.0
# value                                        0         0.0
# description                                  0         0.0
# id                                           0         0.0
# datacollectionperiod                         0         0.0
# datacollection                               0         0.0
# scenario                                     0         0.0
# geographic_unit                              0         0.0
# datasourceorganization                       0         0.0
# datasourcedocument                           0         0.0
# dataseries                                   0         0.0
# dataseries_name                              0         0.0
# specialization_type                          0         0.0
# dataseries_specialization_type               0         0.0
# data_usage_policy                            0         0.0
# created                                      0         0.0
# modified                                     0         0.0
# status_changed                               0         0.0
# collection_status                            0         0.0
# collection_status_changed                    0         0.0
# collection_schedule                          0         0.0
# reporting_date                               0         0.0

# %%
duplicates = df.duplicated().sum()

print("Duplicate rows:", duplicates)
# Out:
# Duplicate rows: 0

# %%
for col in df.columns:
    print(col)
# Out:
# row
# source_organization
# source_document
# country
# country_code
# geographic_group
# fewsnet_region
# geographic_unit_full_name
# geographic_unit_name
# unit_type
# fnid
# classification_scale
# scenario_name
# preference_rating
# is_allowing_for_assistance
# projection_start
# projection_end
# status
# value
# pct_phase3
# pct_phase4
# pct_phase5
# description
# id
# datacollectionperiod
# datacollection
# scenario
# geographic_unit
# datasourceorganization
# datasourcedocument
# dataseries
# dataseries_name
# specialization_type
# dataseries_specialization_type
# data_usage_policy
# created
# modified
# status_changed
# collection_status
# collection_status_changed
# collection_schedule
# reporting_date

# %%
print(f"Rows: {df.shape[0]:,}")
print(f"Columns: {df.shape[1]}")
# Out:
# Rows: 27,694
# Columns: 42

# %%
df.dtypes
# Out:
# row                                 int64
# source_organization                   str
# source_document                       str
# country                               str
# country_code                          str
# geographic_group                      str
# fewsnet_region                        str
# geographic_unit_full_name             str
# geographic_unit_name                  str
# unit_type                             str
# fnid                                  str
# classification_scale                  str
# scenario_name                         str
# preference_rating                   int64
# is_allowing_for_assistance           bool
# projection_start                      str
# projection_end                        str
# status                                str
# value                             float64
# pct_phase3                        float64
# pct_phase4                        float64
# pct_phase5                        float64
# description                           str
# id                                  int64
# datacollectionperiod                int64
# datacollection                      int64
# scenario                              str
# geographic_unit                     int64
# datasourceorganization              int64
# datasourcedocument                  int64
# dataseries                          int64
# dataseries_name                       str
# specialization_type                   str
# dataseries_specialization_type        str
# data_usage_policy                     str
# created                               str
# modified                              str
# status_changed                        str
# collection_status                     str
# collection_status_changed             str
# collection_schedule                   str
# reporting_date                        str
# dtype: object

# %%
df.memory_usage(deep=True)
# Out:
# Index                                 132
# row                                221552
# source_organization               1578558
# source_document                   2132438
# country                           1495476
# country_code                      1412394
# geographic_group                  1744722
# fewsnet_region                    1661640
# geographic_unit_full_name         2802218
# geographic_unit_name              1974368
# unit_type                         1677912
# fnid                              1780142
# classification_scale              1550864
# scenario_name                     1827804
# preference_rating                  221552
# is_allowing_for_assistance          27694
# projection_start                  1633946
# projection_end                    1633946
# status                            1606252
# value                              221552
# pct_phase3                         221552
# pct_phase4                         221552
# pct_phase5                         221552
# description                       1556306
# id                                 221552
# datacollectionperiod               221552
# datacollection                     221552
# scenario                          1412394
# geographic_unit                    221552
# datasourceorganization             221552
# datasourcedocument                 221552
# dataseries                         221552
# dataseries_name                   4954088
# specialization_type               1633946
# dataseries_specialization_type    1883192
# data_usage_policy                 1523170
# created                           1883192
# modified                          1883192
# status_changed                    1883192
# collection_status                 1606252
# collection_status_changed         1883192
# collection_schedule               1523170
# reporting_date                    1633946
# dtype: int64
